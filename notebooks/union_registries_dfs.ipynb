# %%
import pandas as pd

# %% [markdown]
# # Load EUTL dataset
# - Source
#     - The reason why a same transaction (with one TRANSACTION_ID) is described by multiple lines is because the file details transactions by ORIGINATING_REGISTRY, UNIT_TYPE_DESCRIPTION, SUPP_UNIT_TYPE_DESCRIPTION, ORIGINAL_PERIOD_CODE, LULUCF_CODE_DESCRIPTION, PROJECT_IDENTIFIER, TRACK and EXPIRY_DATE, which can be many for one transaction
# - Information of EUTL: X EUAs are trasnferred from account A to account B on date T
# - [Abrell](https://www.euets.info/) support tools:
#     - [scraper](https://github.com/jabrell/eutl_scraper): provides access to the Python routines for downloading and processing of the source data
#     - [pyeutl](https://github.com/jabrell/pyeutl/tree/main): provides Python routines to access the data provided in a convenient way
#     - [transactions_analysis](https://github.com/jabrell/transaction_eutl)

# %% [markdown]
# ## Transactions

# %% [markdown]
# ### Check optimal dtypes
# - based on number of unique values, set as category or string

# %%
df_eutl_2022 = pd.read_csv(r'../data/raw/transactions_eutl_2025/transactions_EUTL_PUBLIC_NOTESD_20251031.csv', nrows = 10000)

for col in df_eutl_2022.select_dtypes(include="object"):
    print(f"{col}: {df_eutl_2022[col].nunique(dropna=False) / len(df_eutl_2022)}")
# Out:
# TRANSACTION_ID: 0.7958
# TRANSACTION_TYPE: 0.0004
# TRANSACTION_DATE: 0.79
# TRANSACTION_STATUS: 0.0001
# TRANSFERRING_REGISTRY_NAME: 0.0033
# TRANSFERRING_ACCOUNT_TYPE2: 0.0004
# TRANSFERRING_ACCOUNT_TYPE3: 0.0007
# TRANSFERRING_ACCOUNT_OPEN_DT: 0.144
# TRANSFERRING_ACCOUNT_END_OF_VALIDITY: 0.0655
# TRANSFERRING_ACCOUNT_NAME: 0.2351
# TRANSFERRING_ACCOUNT_HOLDER: 0.1922
# TRANSFERRING_ACCOUNT_HOLDER_ADDRESS1: 0.1836
# TRANSFERRING_ACCOUNT_HOLDER_ADDRESS2: 0.0475
# TRANSFERRING_ACCOUNT_HOLDER_CITY: 0.1294
# TRANSFERRING_ACCOUNT_HOLDER_POSTAL_CODE: 0.1552
# TRANSFERRING_ACCOUNT_HOLDER_COUNTRY_CODE: 0.0045
# TRANSFERRING_ACCOUNT_HOLDER_COMPANY_REGISTRATION_NUMBER: 0.1879
# TRANSFERRING_ACCOUNT_HOLDER_LEI: 0.0574
# TRANSFERRING_INSTALLATION_NAME: 0.1836
# TRANSFERRING_INSTALLATION_PERMIT_IDENTIFIER: 0.1862
# TRANSFERRING_INSTALLATION_PARENT_COMPANY: 0.0399
# TRANSFERRING_INSTALLATION_SUBSIDIARY_COMPANY: 0.0111
# TRANSFERRING_INSTALLATION_EPER_IDENTIFICATION: 0.0633
# TRANSFERRING_INSTALLATION_CITY: 0.1476
# TRANSFERRING_INSTALLATION_POSTAL_CODE: 0.1518
# TRANSFERRING_INSTALLATION_ADDRESS1: 0.171
# TRANSFERRING_INSTALLATION_ADDRESS2: 0.0314
# TRANSFERRING_INSTALLATION_MAIN_ACTIVITY: 0.0033
# ACQUIRING_REGISTRY_NAME: 0.0032
# ACQUIRING_ACCOUNT_TYPE2: 0.0003
# ACQUIRING_ACCOUNT_TYPE3: 0.0008
# ACQUIRING_ACCOUNT_OPEN_DT: 0.151
# ACQUIRING_ACCOUNT_END_OF_VALIDITY: 0.0722
# ACQUIRING_ACCOUNT_NAME: 0.2671
# ACQUIRING_ACCOUNT_HOLDER: 0.2138
# ACQUIRING_ACCOUNT_HOLDER_ADDRESS1: 0.2058
# ACQUIRING_ACCOUNT_HOLDER_ADDRESS2: 0.0536
# ACQUIRING_ACCOUNT_HOLDER_CITY: 0.1457
# ACQUIRING_ACCOUNT_HOLDER_POSTAL_CODE: 0.1704
# ACQUIRING_ACCOUNT_HOLDER_COUNTRY_CODE: 0.0046
# ACQUIRING_ACCOUNT_HOLDER_COMPANY_REGISTRATION_NUMBER: 0.209
# ACQUIRING_ACCOUNT_HOLDER_LEI: 0.0688
# ACQUIRING_INSTALLATION_NAME: 0.222
# ACQUIRING_INSTALLATION_PERMIT_IDENTIFIER: 0.2252
# ACQUIRING_INSTALLATION_PARENT_COMPANY: 0.0434
# ACQUIRING_INSTALLATION_SUBSIDIARY_COMPANY: 0.0116
# ACQUIRING_INSTALLATION_EPER_IDENTIFICATION: 0.0807
# ACQUIRING_INSTALLATION_CITY: 0.1724
# ACQUIRING_INSTALLATION_POSTAL_CODE: 0.1771
# ACQUIRING_INSTALLATION_ADDRESS1: 0.2043
# ACQUIRING_INSTALLATION_ADDRESS2: 0.0352
# ACQUIRING_INSTALLATION_MAIN_ACTIVITY: 0.0033
# ORIGINATING_REGISTRY: 0.0067
# UNIT_TYPE_DESCRIPTION: 0.0003
# SUPP_UNIT_TYPE_DESCRIPTION: 0.0001
# LULUCF_CODE_DESCRIPTION: 0.0002
# C:\Users\ATapia\AppData\Local\Temp\ipykernel_20784\203569506.py:1: DtypeWarning: Columns (0: LULUCF_CODE_DESCRIPTION) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_eutl_2022 = pd.read_csv(r'../data/raw/transactions_eutl_2025/transactions_EUTL_PUBLIC_NOTESD_20251031.csv', nrows = 10000)
# C:\Users\ATapia\AppData\Local\Temp\ipykernel_20784\203569506.py:3: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   for col in df_eutl_2022.select_dtypes(include="object"):

# %%
dtypes = {
    # IDs / keys
    "TRANSACTION_ID": "string",

    # Low-cardinality / codes
    "TRANSACTION_TYPE": "category",
    "TRANSACTION_STATUS": "category",

    "TRANSFERRING_REGISTRY_NAME": "category",
    "ACQUIRING_REGISTRY_NAME": "category",
    "ORIGINATING_REGISTRY": "category",

    "TRANSFERRING_ACCOUNT_TYPE2": "category",
    "TRANSFERRING_ACCOUNT_TYPE3": "category",
    "ACQUIRING_ACCOUNT_TYPE2": "category",
    "ACQUIRING_ACCOUNT_TYPE3": "category",

    "TRANSFERRING_ACCOUNT_HOLDER_COUNTRY_CODE": "category",
    "ACQUIRING_ACCOUNT_HOLDER_COUNTRY_CODE": "category",

    "TRANSFERRING_INSTALLATION_MAIN_ACTIVITY": "category",
    "ACQUIRING_INSTALLATION_MAIN_ACTIVITY": "category",

    "UNIT_TYPE_DESCRIPTION": "category",
    "SUPP_UNIT_TYPE_DESCRIPTION": "category",
    "LULUCF_CODE_DESCRIPTION": "string",  # force away mixed types; you can later .astype("category") if you want

    # Lower-cardinality text (often worth category)
    "TRANSFERRING_INSTALLATION_PARENT_COMPANY": "category",
    "TRANSFERRING_INSTALLATION_SUBSIDIARY_COMPANY": "category",
    "ACQUIRING_INSTALLATION_PARENT_COMPANY": "category",
    "ACQUIRING_INSTALLATION_SUBSIDIARY_COMPANY": "category",

    "TRANSFERRING_ACCOUNT_HOLDER_LEI": "category",
    "ACQUIRING_ACCOUNT_HOLDER_LEI": "category",

    "TRANSFERRING_ACCOUNT_HOLDER_ADDRESS2": "category",
    "ACQUIRING_ACCOUNT_HOLDER_ADDRESS2": "category",
    "TRANSFERRING_INSTALLATION_ADDRESS2": "category",
    "ACQUIRING_INSTALLATION_ADDRESS2": "category",

    "TRANSFERRING_INSTALLATION_EPER_IDENTIFICATION": "category",
    "ACQUIRING_INSTALLATION_EPER_IDENTIFICATION": "category",

    # High-ish cardinality text -> string (safe default)
    "TRANSFERRING_ACCOUNT_NAME": "string",
    "TRANSFERRING_ACCOUNT_HOLDER": "string",
    "TRANSFERRING_ACCOUNT_HOLDER_ADDRESS1": "string",
    "TRANSFERRING_ACCOUNT_HOLDER_CITY": "string",
    "TRANSFERRING_ACCOUNT_HOLDER_POSTAL_CODE": "string",
    "TRANSFERRING_ACCOUNT_HOLDER_COMPANY_REGISTRATION_NUMBER": "string",

    "TRANSFERRING_INSTALLATION_NAME": "string",
    "TRANSFERRING_INSTALLATION_PERMIT_IDENTIFIER": "string",
    "TRANSFERRING_INSTALLATION_CITY": "string",
    "TRANSFERRING_INSTALLATION_POSTAL_CODE": "string",
    "TRANSFERRING_INSTALLATION_ADDRESS1": "string",

    "ACQUIRING_ACCOUNT_NAME": "string",
    "ACQUIRING_ACCOUNT_HOLDER": "string",
    "ACQUIRING_ACCOUNT_HOLDER_ADDRESS1": "string",
    "ACQUIRING_ACCOUNT_HOLDER_CITY": "string",
    "ACQUIRING_ACCOUNT_HOLDER_POSTAL_CODE": "string",
    "ACQUIRING_ACCOUNT_HOLDER_COMPANY_REGISTRATION_NUMBER": "string",

    "ACQUIRING_INSTALLATION_NAME": "string",
    "ACQUIRING_INSTALLATION_PERMIT_IDENTIFIER": "string",
    "ACQUIRING_INSTALLATION_CITY": "string",
    "ACQUIRING_INSTALLATION_POSTAL_CODE": "string",
    "ACQUIRING_INSTALLATION_ADDRESS1": "string",
}

# %% [markdown]
# ### Set columns of interest and read

# %%
cols = ['TRANSACTION_ID', 'TRANSACTION_TYPE', 'TRANSACTION_DATE', 'TRANSFERRING_REGISTRY_NAME','TRANSFERRING_ACCOUNT_NAME',
       'TRANSFERRING_ACCOUNT_IDENTIFIER', 'TRANSFERRING_ACCOUNT_HOLDER', 'TRANSFERRING_ACCOUNT_HOLDER_COMPANY_REGISTRATION_NUMBER',
       'TRANSFERRING_ACCOUNT_HOLDER_LEI', 'TRANSFERRING_INSTALLATION_NAME',
       'TRANSFERRING_INSTALLATION_INSTALLATION_IDENTIFIER','TRANSFERRING_INSTALLATION_PARENT_COMPANY',
       'TRANSFERRING_INSTALLATION_SUBSIDIARY_COMPANY','TRANSFERRING_INSTALLATION_MAIN_ACTIVITY', 'ACQUIRING_REGISTRY_NAME','ACQUIRING_ACCOUNT_NAME',
       'ACQUIRING_ACCOUNT_IDENTIFIER', 'ACQUIRING_ACCOUNT_HOLDER','ACQUIRING_ACCOUNT_HOLDER_LEI', 'ACQUIRING_INSTALLATION_NAME',
       'ACQUIRING_INSTALLATION_INSTALLATION_IDENTIFIER','ACQUIRING_INSTALLATION_PARENT_COMPANY',
       'ACQUIRING_INSTALLATION_SUBSIDIARY_COMPANY']

# %%
df_eutl_2022 = pd.read_csv(
    "../data/raw/transactions_eutl_2025/transactions_EUTL_PUBLIC_NOTESD_20251031.csv",
    #usecols=cols,
    dtype=dtypes,
    parse_dates=["TRANSACTION_DATE"],
    low_memory=False    # internal chunksize is not customizable in python, so in order to avoid mixed types we need to disable it entirely
)

# %%
df_eutl_2022.info(memory_usage="deep")
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2142475 entries, 0 to 2142474
# Data columns (total 67 columns):
#  #   Column                                                   Dtype
# ---  ------                                                   -----
#  0   TRANSACTION_ID                                           string
#  1   TRANSACTION_TYPE                                         category
#  2   TRANSACTION_DATE                                         datetime64[us]
#  3   TRANSACTION_STATUS                                       category
#  4   TRANSFERRING_REGISTRY_NAME                               category
#  5   TRANSFERRING_ACCOUNT_TYPE1                               float64
#  6   TRANSFERRING_ACCOUNT_TYPE2                               category
#  7   TRANSFERRING_ACCOUNT_TYPE3                               category
#  8   TRANSFERRING_ACCOUNT_OPEN_DT                             str
#  9   TRANSFERRING_ACCOUNT_END_OF_VALIDITY                     str
#  10  TRANSFERRING_ACCOUNT_NAME                                string
#  11  TRANSFERRING_ACCOUNT_IDENTIFIER                          float64
#  12  TRANSFERRING_ACCOUNT_HOLDER                              string
#  13  TRANSFERRING_ACCOUNT_HOLDER_ADDRESS1                     string
#  14  TRANSFERRING_ACCOUNT_HOLDER_ADDRESS2                     category
#  15  TRANSFERRING_ACCOUNT_HOLDER_CITY                         string
#  16  TRANSFERRING_ACCOUNT_HOLDER_POSTAL_CODE                  string
#  17  TRANSFERRING_ACCOUNT_HOLDER_COUNTRY_CODE                 category
#  18  TRANSFERRING_ACCOUNT_HOLDER_COMPANY_REGISTRATION_NUMBER  string
#  19  TRANSFERRING_ACCOUNT_HOLDER_LEI                          category
#  20  TRANSFERRING_INSTALLATION_NAME                           string
#  21  TRANSFERRING_INSTALLATION_INSTALLATION_IDENTIFIER        float64
#  22  TRANSFERRING_INSTALLATION_PERMIT_IDENTIFIER              string
#  23  TRANSFERRING_INSTALLATION_PARENT_COMPANY                 category
#  24  TRANSFERRING_INSTALLATION_SUBSIDIARY_COMPANY             category
#  25  TRANSFERRING_INSTALLATION_EPER_IDENTIFICATION            category
#  26  TRANSFERRING_INSTALLATION_CITY                           string
#  27  TRANSFERRING_INSTALLATION_POSTAL_CODE                    string
#  28  TRANSFERRING_INSTALLATION_ADDRESS1                       string
#  29  TRANSFERRING_INSTALLATION_ADDRESS2                       category
#  30  TRANSFERRING_INSTALLATION_MAIN_ACTIVITY                  category
#  31  ACQUIRING_REGISTRY_NAME                                  category
#  32  ACQUIRING_ACCOUNT_TYPE1                                  int64
#  33  ACQUIRING_ACCOUNT_TYPE2                                  category
#  34  ACQUIRING_ACCOUNT_TYPE3                                  category
#  35  ACQUIRING_ACCOUNT_OPEN_DT                                str
#  36  ACQUIRING_ACCOUNT_END_OF_VALIDITY                        str
#  37  ACQUIRING_ACCOUNT_NAME                                   string
#  38  ACQUIRING_ACCOUNT_IDENTIFIER                             int64
#  39  ACQUIRING_ACCOUNT_HOLDER                                 string
#  40  ACQUIRING_ACCOUNT_HOLDER_ADDRESS1                        string
#  41  ACQUIRING_ACCOUNT_HOLDER_ADDRESS2                        category
#  42  ACQUIRING_ACCOUNT_HOLDER_CITY                            string
#  43  ACQUIRING_ACCOUNT_HOLDER_POSTAL_CODE                     string
#  44  ACQUIRING_ACCOUNT_HOLDER_COUNTRY_CODE                    category
#  45  ACQUIRING_ACCOUNT_HOLDER_COMPANY_REGISTRATION_NUMBER     string
#  46  ACQUIRING_ACCOUNT_HOLDER_LEI                             category
#  47  ACQUIRING_INSTALLATION_NAME                              string
#  48  ACQUIRING_INSTALLATION_INSTALLATION_IDENTIFIER           float64
#  49  ACQUIRING_INSTALLATION_PERMIT_IDENTIFIER                 string
#  50  ACQUIRING_INSTALLATION_PARENT_COMPANY                    category
#  51  ACQUIRING_INSTALLATION_SUBSIDIARY_COMPANY                category
#  52  ACQUIRING_INSTALLATION_EPER_IDENTIFICATION               category
#  53  ACQUIRING_INSTALLATION_CITY                              string
#  54  ACQUIRING_INSTALLATION_POSTAL_CODE                       string
#  55  ACQUIRING_INSTALLATION_ADDRESS1                          string
#  56  ACQUIRING_INSTALLATION_ADDRESS2                          category
#  57  ACQUIRING_INSTALLATION_MAIN_ACTIVITY                     category
#  58  ORIGINATING_REGISTRY                                     category
#  59  UNIT_TYPE_DESCRIPTION                                    category
#  60  SUPP_UNIT_TYPE_DESCRIPTION                               category
#  61  ORIGINAL_PERIOD_CODE                                     int64
#  62  LULUCF_CODE_DESCRIPTION                                  string
#  63  PROJECT_IDENTIFIER                                       float64
#  64  TRACK                                                    float64
#  65  EXPIRY_DATE                                              str
#  66  AMOUNT                                                   int64
# dtypes: category(27), datetime64[us](1), float64(6), int64(4), str(5), string(24)
# memory usage: 4.2 GB

# %%
df_eutl_2022.nunique().sort_values(ascending=False)
# Out:
# TRANSACTION_ID                1308391
# TRANSACTION_DATE              1160602
# AMOUNT                         174939
# ACQUIRING_ACCOUNT_NAME          22765
# TRANSFERRING_ACCOUNT_NAME       22405
#                                ...
# TRANSFERRING_ACCOUNT_TYPE2          5
# ORIGINAL_PERIOD_CODE                4
# EXPIRY_DATE                         3
# TRACK                               2
# TRANSACTION_STATUS                  1
# Length: 67, dtype: int64

# %%
df_eutl_2022
# Out:
#         TRANSACTION_ID TRANSACTION_TYPE    TRANSACTION_DATE  \
# 0             DE122558             10-0 2015-06-04 17:38:44
# 1              GB66629             10-0 2012-08-28 15:29:28
# 2              NL28978             10-0 2012-09-12 17:25:39
# 3              NL28981             10-0 2012-09-13 15:45:37
# 4              NL29004             10-0 2012-09-18 14:23:50
# ...                ...              ...                 ...
# 2142470       EU542433             10-2 2020-01-09 18:14:20
# 2142471        FR93298             10-0 2009-05-07 17:26:34
# 2142472        FR10339             10-0 2006-06-01 16:34:39
# 2142473       EU403486             10-2 2017-04-27 13:28:12
# 2142474       EU528943             10-0 2019-08-23 13:43:04
#
#         TRANSFERRING_REGISTRY_NAME  \
# 0                          Germany
# 1                   United Kingdom
# 2                      Netherlands
# 3                      Netherlands
# 4                      Netherlands
# ...                            ...
# 2142470                      Spain
# 2142471                    France
# 2142472                    France
# 2142473                    Romania
# 2142474                Netherlands
#
#                             TRANSFERRING_ACCOUNT_NAME  \
# 0                  1914 - RWE Power AG  Personenkonto
# 1                      MLI Emissions Registry Account
# 2                                     SIA Vidzeme Eko
# 3                                     SIA Vidzeme Eko
# 4                                     SIA Vidzeme Eko
# ...                                               ...
# 2142470     Tereos Starch & Sweeteners Iberia, S.A.U.
# 2142471                                     CONSUS FR
# 2142472  Caisse des dépôts et consignations Détention
# 2142473                              Operator Account
# 2142474              Vertis Environmental Finance Ltd
#
#          TRANSFERRING_ACCOUNT_IDENTIFIER  \
# 0                                 1914.0
# 1                                  901.0
# 2                                  286.0
# 3                                  286.0
# 4                                  286.0
# ...                                  ...
# 2142470                        5008918.0
# 2142471                           1287.0
# 2142472                           1163.0
# 2142473                        5010063.0
# 2142474                        5017659.0
#
#                        TRANSFERRING_ACCOUNT_HOLDER  \
# 0                     RWE Power Aktiengesellschaft
# 1                      Merrill Lynch International
# 2                                SIA "Vidzeme Eko"
# 3                                SIA "Vidzeme Eko"
# 4                                SIA "Vidzeme Eko"
# ...                                            ...
# 2142470  Tereos Starch & Sweeteners Iberia, S.A.U.
# 2142471                         CONSUS FRANCE SARL
# 2142472         Caisse des Dépôts et Consignations
# 2142473              COMPLEXUL ENERGETIC HUNEDOARA
# 2142474           Vertis Environmental Finance Ltd
#
#         TRANSFERRING_ACCOUNT_HOLDER_COMPANY_REGISTRATION_NUMBER  \
# 0                              HRB 17420 Amtsgericht Essen
# 1                                                 02312079
# 2                                              40003755312
# 3                                              40003755312
# 4                                              40003755312
# ...                                                    ...
# 2142470                                          A50012921
# 2142471                                          491808804
# 2142472                                          180020026
# 2142473                                       J20/994/2012
# 2142474                                           80897959
#
#         TRANSFERRING_ACCOUNT_HOLDER_LEI  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# ...                                 ...
# 2142470                             NaN
# 2142471                             NaN
# 2142472                             NaN
# 2142473                             NaN
# 2142474                             NaN
#
#                     TRANSFERRING_INSTALLATION_NAME  ...  \
# 0                                             <NA>  ...
# 1                                             <NA>  ...
# 2                                             <NA>  ...
# 3                                             <NA>  ...
# 4                                             <NA>  ...
# ...                                            ...  ...
# 2142470  Tereos Starch & Sweeteners Iberia, S.A.U.  ...
# 2142471                                       <NA>  ...
# 2142472                                       <NA>  ...
# 2142473                       Electrocentrale Deva  ...
# 2142474                                       <NA>  ...
#
#          TRANSFERRING_INSTALLATION_MAIN_ACTIVITY ACQUIRING_REGISTRY_NAME  \
# 0                                              -                 Germany
# 1                                              -          United Kingdom
# 2                                              -             Netherlands
# 3                                              -             Netherlands
# 4                                              -             Netherlands
# ...                                          ...                     ...
# 2142470                   20-Combustion of fuels     European Commission
# 2142471                                        -                 France
# 2142472                                        -                 France
# 2142473                   20-Combustion of fuels     European Commission
# 2142474                                        -                 Hungary
#
#                         ACQUIRING_ACCOUNT_NAME ACQUIRING_ACCOUNT_IDENTIFIER  \
# 0        FutureCamp Climate GmbH Personenkonto                         2963
# 1                                         MLCE                          841
# 2                                   ACT Carbon                          778
# 3                                   ACT Carbon                          778
# 4                                   ACT Carbon                          778
# ...                                        ...                          ...
# 2142470                  EU Allowance deletion                      5016380
# 2142471                          CONSUS FR PWX                         1291
# 2142472            ACCORD ENERGY LTD Détention                         1185
# 2142473                  EU Allowance deletion                      5016380
# 2142474           MIHŐ Kft. Diósgyőri kazánház                      5011776
#
#                            ACQUIRING_ACCOUNT_HOLDER  \
# 0                           FutureCamp Climate GmbH
# 1        Merrill Lynch Commodities (Europe) Limited
# 2                      ACT Financial Solutions B.V.
# 3                      ACT Financial Solutions B.V.
# 4                      ACT Financial Solutions B.V.
# ...                                             ...
# 2142470                         European Commission
# 2142471                                    KLAPUCKI
# 2142472                                  WINKLEHNER
# 2142473                         European Commission
# 2142474            MIHÕ Miskolci Hõszolgáltató Kft.
#
#         ACQUIRING_ACCOUNT_HOLDER_LEI   ACQUIRING_INSTALLATION_NAME  \
# 0                                NaN                          <NA>
# 1                                NaN                          <NA>
# 2             724500LY73GPE4GDX159\r                          <NA>
# 3             724500LY73GPE4GDX159\r                          <NA>
# 4             724500LY73GPE4GDX159\r                          <NA>
# ...                              ...                           ...
# 2142470                          NaN                          <NA>
# 2142471                          NaN                          <NA>
# 2142472                          NaN                          <NA>
# 2142473                          NaN                          <NA>
# 2142474                          NaN  MIHŐ Kft. Diósgyőri kazánház
#
#         ACQUIRING_INSTALLATION_INSTALLATION_IDENTIFIER  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ...                                                ...
# 2142470                                            NaN
# 2142471                                            NaN
# 2142472                                            NaN
# 2142473                                            NaN
# 2142474                                          146.0
#
#         ACQUIRING_INSTALLATION_PARENT_COMPANY  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ...                                       ...
# 2142470                                   NaN
# 2142471                                   NaN
# 2142472                                   NaN
# 2142473                                   NaN
# 2142474                                   NaN
#
#         ACQUIRING_INSTALLATION_SUBSIDIARY_COMPANY
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ...                                           ...
# 2142470                                       NaN
# 2142471                                       NaN
# 2142472                                       NaN
# 2142473                                       NaN
# 2142474                                       NaN
#
# [2142475 rows x 23 columns]

# %%
df_eutl_2022.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_eutl_2022['TRANSACTION_DATE'].sort_values()
# Out:
# 248759    2005-01-11 13:43:06
# 1394727   2005-02-01 11:17:29
# 1320551   2005-02-01 11:17:34
# 248858    2005-02-01 11:17:38
# 995909    2005-02-01 11:17:42
#                   ...
# 905217    2022-09-30 16:46:40
# 825280    2022-09-30 17:16:04
# 1317962   2022-09-30 17:25:07
# 1498982   2022-09-30 17:25:07
# 1523643   2022-09-30 17:30:38
# Name: TRANSACTION_DATE, Length: 2142475, dtype: datetime64[us]

# %%
pd.read_csv(r'../data/raw/transactions_eutl_2025/transactions_EUTL_PUBLIC_NOTESD_20251031.csv', usecols=['UNIT_TYPE_DESCRIPTION']).value_counts()
# Out:
# UNIT_TYPE_DESCRIPTION
# AAU - Assigned Amount Unit                                       1054991
# Non-Kyoto Unit                                                    708724
# CER - Certified Emission Reduction Unit converted from an AAU     324244
# ERU - Emission Reduction Unit                                      54135
# tCER - Temporary CER                                                 217
# RMU - Removal Unit                                                   130
# ERU - Converted from an RMU                                           34
# Name: count, dtype: int64

# %% [markdown]
# ### Check row unique identifier

# %%
df_trans_dupl = df_eutl_2022[df_eutl_2022['TRANSACTION_ID'].duplicated(keep=False)].sort_values('TRANSACTION_ID')

# %%
df_trans_dupl

# %%
# see abrel id

pd.read_csv(r"../data/raw/abrel_postgres_files/transactionBlocks.csv", nrows=0).columns
# Out:
# Index(['transactionID', 'transactionDate', 'originatingRegistry', 'projectID',
#        'projectTrack', 'amount', 'transferringAccountName',
#        'acquiringAccountName', 'transferringAccountIdentifier',
#        'acquiringAccountIdentifier', 'transactionTypeMain_id',
#        'transactionTypeSupplementary_id', 'unitType_id',
#        'acquiringRegistryCode', 'acquiringAccountIdentifierDB',
#        'transferringRegistryCode', 'transferringAccountIdentifierDB',
#        'acquiringAccountID', 'transferringAccountID'],
#       dtype='str')

# %%
abrel_trans = pd.read_csv(r"../data/raw/abrel_postgres_files/transactionBlocks.csv")

# %%
abrel_trans.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1875818 entries, 0 to 1875817
# Data columns (total 19 columns):
#  #   Column                           Dtype
# ---  ------                           -----
#  0   transactionID                    str
#  1   transactionDate                  str
#  2   originatingRegistry              str
#  3   projectID                        float64
#  4   projectTrack                     float64
#  5   amount                           int64
#  6   transferringAccountName          str
#  7   acquiringAccountName             str
#  8   transferringAccountIdentifier    float64
#  9   acquiringAccountIdentifier       int64
#  10  transactionTypeMain_id           int64
#  11  transactionTypeSupplementary_id  int64
#  12  unitType_id                      str
#  13  acquiringRegistryCode            str
#  14  acquiringAccountIdentifierDB     str
#  15  transferringRegistryCode         str
#  16  transferringAccountIdentifierDB  str
#  17  acquiringAccountID               float64
#  18  transferringAccountID            float64
# dtypes: float64(5), int64(4), str(10)
# memory usage: 271.9 MB

# %%
abrel_trans['transactionID'].value_counts().head(20)
# Out:
# transactionID
# EU300768     738
# IT36446      677
# EU300773     677
# DE122804     601
# EU300802     601
# EU300801     567
# DE122803     567
# EU233750     562
# ES1065195    534
# EU300764     534
# EU300788     485
# EU236457     469
# EU215791     431
# PL30630      422
# EU234795     408
# EU235259     406
# EU238766     384
# EU231985     379
# EU240881     376
# EU239521     376
# Name: count, dtype: int64

# %%
abrel_trans[abrel_trans['transactionID'] == 'EU300768']
# Out:
# 3325                         EU_5022590            111096.0
# 4537                         EU_5022590            111096.0
# 5078                         EU_5022590            111096.0
# 7945                         EU_5022590            111096.0
# 7995                         EU_5022590            111096.0
# ...                                 ...                 ...
# 1870326                      EU_5022590            111096.0
# 1871306                      EU_5022590            111096.0
# 1872151                      EU_5022590            111096.0
# 1873590                      EU_5022590            111096.0
# 1874629                      EU_5022590            111096.0
#
#          transferringAccountID
# 3325                  111266.0
# 4537                  111266.0
# 5078                  111266.0
# 7945                  111266.0
# 7995                  111266.0
# ...                        ...
# 1870326               111266.0
# 1871306               111266.0
# 1872151               111266.0
# 1873590               111266.0
# 1874629               111266.0
#
# [738 rows x 19 columns]

# %%
abrel_trans.nunique()
# Out:
# transactionID                      1139520
# transactionDate                    1027667
# originatingRegistry                    111
# projectID                             3528
# projectTrack                             2
# amount                              159336
# transferringAccountName              21561
# acquiringAccountName                 21727
# transferringAccountIdentifier        21463
# acquiringAccountIdentifier           20572
# transactionTypeMain_id                   9
# transactionTypeSupplementary_id         41
# unitType_id                             11
# acquiringRegistryCode                   35
# acquiringAccountIdentifierDB         31936
# transferringRegistryCode                42
# transferringAccountIdentifierDB      33237
# acquiringAccountID                   31917
# transferringAccountID                32474
# dtype: int64

# %% [markdown]
# ## Compliance

# %%
pd.read_excel(r"../data/raw/compliance_2024_code_en.xlsx" ,nrows=0, header=1).columns.to_list()
# Out:
# ['REGISTRY_CODE',
#  'INSTALLATION_NAME',
#  'INSTALLATION_IDENTIFIER',
#  'PERMIT_IDENTIFIER',
#  'MAIN_ACTIVITY_TYPE_CODE',
#  'COMPLIANCE_CODE',
#  'CH_COMPLIANCE_CODE',
#  'COMPLIANCE_STATUS_LATEST_YEAR',
#  'TOTAL_VERIFIED_EMISSIONS',
#  'CH_TOTAL_VERIFIED_EMISSIONS',
#  'TOTAL_SURRENDERED_ALLOWANCES',
#  'YEAR_OF_FIRST_EMISSIONS',
#  'YEAR_OF_LAST_EMISSIONS',
#  'ACCOUNT_CLOSURE']

# %%
df_compliance = pd.read_excel(r"../data/raw/compliance_2024_code_en.xlsx" , header=1)

# %%
df_compliance.shape
# Out:
# (14573, 14)

# %%
df_compliance[df_compliance.duplicated(subset=['INSTALLATION_IDENTIFIER', 'REGISTRY_CODE'],keep=False)]
# Out:
#      REGISTRY_CODE INSTALLATION_NAME  INSTALLATION_IDENTIFIER  \
# 6849            FR              3329                   204199
# 6850            FR              3329                   204199
#
#        PERMIT_IDENTIFIER  MAIN_ACTIVITY_TYPE_CODE      COMPLIANCE_CODE  \
# 6849  3329-10/12/2009-V1                       10  EXCLUDED SINCE 2021
# 6850  3329-10/12/2009-V1                       10  EXCLUDED SINCE 2021
#
#        CH_COMPLIANCE_CODE  COMPLIANCE_STATUS_LATEST_YEAR  \
# 6849  EXCLUDED SINCE 2021                            NaN
# 6850  EXCLUDED SINCE 2021                            NaN
#
#      TOTAL_VERIFIED_EMISSIONS CH_TOTAL_VERIFIED_EMISSIONS  \
# 6849                        0                           0
# 6850                        0                           0
#
#       TOTAL_SURRENDERED_ALLOWANCES  YEAR_OF_FIRST_EMISSIONS  \
# 6849                           109                     2012
# 6850                           218                     2012
#
#      YEAR_OF_LAST_EMISSIONS ACCOUNT_CLOSURE
# 6849                NOT SET            OPEN
# 6850                NOT SET            OPEN

# %%
df_compliance.nunique()
# Out:
# REGISTRY_CODE                       31
# INSTALLATION_NAME                14324
# INSTALLATION_IDENTIFIER           9290
# PERMIT_IDENTIFIER                14450
# MAIN_ACTIVITY_TYPE_CODE             36
# COMPLIANCE_CODE                      6
# CH_COMPLIANCE_CODE                   6
# COMPLIANCE_STATUS_LATEST_YEAR        4
# TOTAL_VERIFIED_EMISSIONS         11063
# CH_TOTAL_VERIFIED_EMISSIONS        208
# TOTAL_SURRENDERED_ALLOWANCES     10657
# YEAR_OF_FIRST_EMISSIONS             20
# YEAR_OF_LAST_EMISSIONS               7
# ACCOUNT_CLOSURE                    255
# dtype: int64

# %%
pd.read_excel(r"../data/raw/compliance_2020_code_en.xlsx" ,nrows=0, header=0).columns.to_list()
# Out:
# ['REGISTRY_CODE',
#  'INSTALLATION_NAME',
#  'INSTALLATION_IDENTIFIER',
#  'PERMIT_IDENTIFIER',
#  'MAIN_ACTIVITY_TYPE_CODE',
#  'COMPLIANCE_CODE',
#  'CH_COMPLIANCE_CODE',
#  'COMPLIANCE_STATUS_LATEST_YEAR',
#  'TOTAL_VERIFIED_EMISSIONS',
#  'CH_TOTAL_VERIFIED_EMISSIONS',
#  'TOTAL_SURRENDERED_ALLOWANCES',
#  'YEAR_OF_FIRST_EMISSIONS',
#  'YEAR_OF_LAST_EMISSIONS',
#  'ACCOUNT_CLOSURE']

# %% [markdown]
# ## Verified enmission
# - Unique id = REGISTRY_CODE + INSTALLATION_IDENTIFIER

# %%
pd.read_excel(r"../data/raw/verified_emissions_2024_en.xlsx" , nrows=0, header=20).columns.to_list()
# Out:
# ['REGISTRY_CODE',
#  'IDENTIFIER_IN_REG',
#  'INSTALLATION_NAME',
#  'INSTALLATION_IDENTIFIER',
#  'PERMIT_IDENTIFIER',
#  'MAIN_ACTIVITY_TYPE_CODE',
#  'ALLOCATION_2024',
#  'ALLOCATION_RESERVE_2024',
#  'ALLOCATION_TRANSITIONAL_2024',
#  'CH_ALLOCATION_2024',
#  'VERIFIED_EMISSIONS_2024',
#  'CH_VERIFIED_EMISSIONS_2024',
#  'ALLOCATION_2023',
#  'ALLOCATION_RESERVE_2023',
#  'ALLOCATION_TRANSITIONAL_2023',
#  'CH_ALLOCATION_2023',
#  'VERIFIED_EMISSIONS_2023',
#  'CH_VERIFIED_EMISSIONS_2023',
#  'ALLOCATION_2022',
#  'ALLOCATION_RESERVE_2022',
#  'ALLOCATION_TRANSITIONAL_2022',
#  'CH_ALLOCATION_2022',
#  'VERIFIED_EMISSIONS_2022',
#  'CH_VERIFIED_EMISSIONS_2022',
#  'ALLOCATION_2021',
#  'ALLOCATION_RESERVE_2021',
#  'ALLOCATION_TRANSITIONAL_2021',
#  'CH_ALLOCATION_2021',
#  'VERIFIED_EMISSIONS_2021',
#  'CH_VERIFIED_EMISSIONS_2021',
#  'ALLOCATION_2020',
#  'ALLOCATION_RESERVE_2020',
#  'ALLOCATION_TRANSITIONAL_2020',
#  'CH_ALLOCATION_2020',
#  'VERIFIED_EMISSIONS_2020',
#  'CH_VERIFIED_EMISSIONS_2020',
#  'ALLOCATION_2019',
#  'ALLOCATION_RESERVE_2019',
#  'ALLOCATION_TRANSITIONAL_2019',
#  'VERIFIED_EMISSIONS_2019',
#  'ALLOCATION_2018',
#  'ALLOCATION_RESERVE_2018',
#  'ALLOCATION_TRANSITIONAL_2018',
#  'VERIFIED_EMISSIONS_2018',
#  'ALLOCATION_2017',
#  'ALLOCATION_RESERVE_2017',
#  'ALLOCATION_TRANSITIONAL_2017',
#  'VERIFIED_EMISSIONS_2017',
#  'ALLOCATION_2016',
#  'ALLOCATION_RESERVE_2016',
#  'ALLOCATION_TRANSITIONAL_2016',
#  'VERIFIED_EMISSIONS_2016',
#  'ALLOCATION_2015',
#  'ALLOCATION_RESERVE_2015',
#  'ALLOCATION_TRANSITIONAL_2015',
#  'VERIFIED_EMISSIONS_2015',
#  'ALLOCATION_2014',
#  'ALLOCATION_RESERVE_2014',
#  'ALLOCATION_TRANSITIONAL_2014',
#  'VERIFIED_EMISSIONS_2014',
#  'ALLOCATION_2013',
#  'ALLOCATION_RESERVE_2013',
#  'ALLOCATION_TRANSITIONAL_2013',
#  'VERIFIED_EMISSIONS_2013',
#  'ALLOCATION_2012',
#  'VERIFIED_EMISSIONS_2012',
#  'ALLOCATION_2011',
#  'VERIFIED_EMISSIONS_2011',
#  'ALLOCATION_2010',
#  'VERIFIED_EMISSIONS_2010',
#  'ALLOCATION_2009',
#  'VERIFIED_EMISSIONS_2009',
#  'ALLOCATION_2008',
#  'VERIFIED_EMISSIONS_2008',
#  'ACCOUNT_CLOSURE',
#  'IMO_ID',
#  'ACCOUNT_TYPE']

# %%
df_map_acts = pd.read_excel(r"../data/raw/verified_emissions_2024_en.xlsx" , sheet_name=1)

# %%
df_map_acts
# Out:
#                                                 value  code
# 0   Combustion installations with a rated thermal ...     1
# 1                              Mineral oil refineries     2
# 2                                          Coke ovens     3
# 3   Metal ore (including sulphide ore) roasting or...     4
# 4   Installations for the production of pig iron o...     5
# 5   Installations for the production of cement cli...     6
# 6   Installations for the manufacture of glass inc...     7
# 7   Installations for the manufacture of ceramic p...     8
# 8   Industrial plants for the production of (a) pu...     9
# 9                        Aircraft operator activities    10
# 10                                Combustion of fuels    20
# 11                            Refining of mineral oil    21
# 12                                 Production of coke    22
# 13                    Metal ore roasting or sintering    23
# 14                    Production of pig iron or steel    24
# 15         Production or processing of ferrous metals    25
# 16                    Production of primary aluminium    26
# 17                  Production of secondary aluminium    27
# 18     Production or processing of non-ferrous metals    28
# 19                       Production of cement clinker    29
# 20  Production of lime, or calcination of dolomite...    30
# 21                               Manufacture of glass    31
# 22                            Manufacture of ceramics    32
# 23                        Manufacture of mineral wool    33
# 24  Production or processing of gypsum or plasterb...    34
# 25                                 Production of pulp    35
# 26                   Production of paper or cardboard    36
# 27                         Production of carbon black    37
# 28                          Production of nitric acid    38
# 29                          Production of adipic acid    39
# 30           Production of glyoxal and glyoxylic acid    40
# 31                              Production of ammonia    41
# 32                       Production of bulk chemicals    42
# 33           Production of hydrogen and synthesis gas    43
# 34      Production of soda ash and sodium bicarbonate    44
# 35  Capture of greenhouse gases under Directive 20...    45
# 36  Transport of greenhouse gases under Directive ...    46
# 37  Storage of greenhouse gases under Directive 20...    47
# 38                                  Maritime Operator    50
# 39  Other activity opted-in pursuant to Article 24...    99

# %%
df_vemiss = pd.read_excel(r"../data/raw/verified_emissions_2024_en.xlsx", header=20)

# %%
df_vemiss

# %%
df_ids = pd.read_excel(r"../data/raw/verified_emissions_2024_en.xlsx" , usecols=['REGISTRY_CODE',
 'IDENTIFIER_IN_REG',
 'INSTALLATION_NAME',
 'INSTALLATION_IDENTIFIER',
 'PERMIT_IDENTIFIER'], header=20)

# %%
df_ids[df_ids[['INSTALLATION_IDENTIFIER', 'REGISTRY_CODE']].duplicated(keep=False)].sort_values('INSTALLATION_IDENTIFIER')
# Out:
# Empty DataFrame
# Columns: [REGISTRY_CODE, IDENTIFIER_IN_REG, INSTALLATION_NAME, INSTALLATION_IDENTIFIER, PERMIT_IDENTIFIER]
# Index: []

# %%
pd.read_excel(r"../data/raw/verified_emissions_2024_en.xlsx" , usecols=['REGISTRY_CODE',
 'IDENTIFIER_IN_REG',
 'INSTALLATION_NAME',
 'INSTALLATION_IDENTIFIER',
 'PERMIT_IDENTIFIER'], header=20).nunique()
# Out:
# REGISTRY_CODE                 32
# IDENTIFIER_IN_REG          16246
# INSTALLATION_NAME          17075
# INSTALLATION_IDENTIFIER     9584
# PERMIT_IDENTIFIER          14692
# dtype: int64

# %% [markdown]
# ### Emissions - Free EUAs

# %%
df_vemiss[['REGISTRY_CODE',
 'IDENTIFIER_IN_REG',
 'INSTALLATION_NAME',
 'INSTALLATION_IDENTIFIER',
'PERMIT_IDENTIFIER']][df_vemiss.duplicated(subset = ['INSTALLATION_IDENTIFIER', 'IDENTIFIER_IN_REG'], keep=False)].sort_values(by ='INSTALLATION_IDENTIFIER')
# Out:
#       REGISTRY_CODE IDENTIFIER_IN_REG  \
# 10078            GB  Operator Account
# 12193            IT  Operator Account
# 11721            IE  Operator Account
# 12734            IT  Operator Account
# 11618            IE  Operator Account
# ...             ...               ...
# 13090            IT  Operator Account
# 9594             GB  Operator Account
# 12717            IT  Operator Account
# 13102            IT  Operator Account
# 9177             GB  Operator Account
#
#                                  INSTALLATION_NAME  INSTALLATION_IDENTIFIER  \
# 10078                                  Rough 47/3B                        2
# 12193            Centrale a Biomasse C&T - Airasca                        2
# 11721                             Kingscourt Works                        2
# 12734  IMPIANTO DI COG. E TELERIS. DI BARDONECCHIA                        3
# 11618         Arrabawn Cooperative Society Limited                        3
# ...                                            ...                      ...
# 13090                    S.p.A. BIRRA PERONI  BARI                      675
# 9594                                 George Square                      682
# 12717                               IDEAL CART SPA                      682
# 13102                            Sampol Italia srl                      704
# 9177                                     Auk Alpha                      704
#
#       PERMIT_IDENTIFIER
# 10078        GB-DTI0200
# 12193            IT-A-2
# 11721         IE-GHG002
# 12734            IT-A-3
# 11618         IE-GHG003
# ...                 ...
# 13090         IT-A-1010
# 9594      UK-S-IN-12354
# 12717         IT-A-1017
# 13102         IT-A-1043
# 9177         GB-DTI9800
#
# [431 rows x 5 columns]

# %%
import re
import numpy as np
import pandas as pd

# Detect years from the emissions columns
years = sorted({
    re.search(r"(\d{4})$", c).group(1)
    for c in df_vemiss.columns
    if c.startswith("VERIFIED_EMISSIONS_") and re.search(r"\d{4}$", c)
})

for y in years:
    a = f"VERIFIED_EMISSIONS_{y}"
    e = f"ALLOCATION_{y}"
    net = f"NET_POSITION_{y}"

    # Coerce to numeric (in case there are strings)
    df_vemiss[e] = pd.to_numeric(df_vemiss[e], errors="coerce")
    df_vemiss[a] = pd.to_numeric(df_vemiss[a], errors="coerce")

    # Treat -1 as missing (blank / not reported)
    df_vemiss.loc[df_vemiss[e] == -1, e] = np.nan
    df_vemiss.loc[df_vemiss[a] == -1, a] = np.nan

    # If you have 'Excluded' values (usually in separate columns, but just in case)
    # convert them to NaN when present as strings
    # (this line is safe even if there are no strings)
    df_vemiss[e] = df_vemiss[e].replace("Excluded", np.nan)
    df_vemiss[a] = df_vemiss[a].replace("Excluded", np.nan)

    # Compute only when both are present; otherwise keep NaN
    df_vemiss[net] = df_vemiss[e] - df_vemiss[a]

# %%
# Get all net position columns automatically
net_cols = [col for col in df_vemiss.columns if col.startswith("NET_POSITION_")]

# Sum across years ignoring NaN
df_vemiss["TOTAL_NET_POSITION"] = df_vemiss[net_cols].sum(axis=1, skipna=True)

# %%
df_vemiss.groupby('MAIN_ACTIVITY_TYPE_CODE').agg(net_by_activity = ('TOTAL_NET_POSITION', 'sum'))
# Out:
#                          net_by_activity
# MAIN_ACTIVITY_TYPE_CODE
# 1                          -2.328770e+08
# 2                          -2.429090e+07
# 4                           1.565660e+05
# 5                           1.301959e+06
# 6                           2.467718e+07
# 7                          -7.482250e+05
# 8                           1.857608e+06
# 9                           1.082914e+07
# 10                         -1.858690e+08
# 20                         -7.603930e+09
# 21                         -2.664265e+08
# 22                         -2.196773e+06
# 23                         -4.217430e+06
# 24                          7.033248e+08
# 25                          3.088939e+07
# 26                         -8.538366e+06
# 27                         -3.409181e+06
# 28                          1.898912e+06
# 29                          2.438940e+08
# 30                          5.264870e+05
# 31                         -2.163222e+07
# 32                          1.461380e+07
# 33                         -2.915414e+06
# 34                         -2.838390e+06
# 35                          2.687571e+07
# 36                          4.190696e+07
# 37                         -1.543191e+06
# 38                          6.385903e+06
# 39                          9.496394e+06
# 40                         -2.152600e+04
# 41                         -2.412362e+07
# 42                          6.714697e+07
# 43                         -8.455910e+06
# 44                          1.219242e+07
# 45                         -3.821700e+04
# 50                          0.000000e+00
# 99                          3.187000e+06

# %% [markdown]
# ### by activity

# %%
import pandas as pd

# 1️⃣ Detect year columns
net_year_cols = [
    c for c in df_vemiss.columns
    if c.startswith("NET_POSITION_")
]

# 2️⃣ Groupby sum for TOTAL + each year
agg_dict = {col: "sum" for col in ["TOTAL_NET_POSITION"] + net_year_cols}

df_net_by_activity = (
    df_vemiss
    .groupby("MAIN_ACTIVITY_TYPE_CODE", dropna=False)
    .agg(agg_dict)
    .reset_index()
)

# 3️⃣ Rename year columns to just the year (cleaner)
rename_dict = {}

for col in net_year_cols:
    year = col.split("_")[-1]   # safer than regex
    rename_dict[col] = year

df_net_by_activity = df_net_by_activity.rename(columns=rename_dict)

# 4️⃣ Merge activity names
df_net_by_activity["MAIN_ACTIVITY_TYPE_CODE"] = pd.to_numeric(
    df_net_by_activity["MAIN_ACTIVITY_TYPE_CODE"], errors="coerce"
)

df_map_acts["code"] = pd.to_numeric(df_map_acts["code"], errors="coerce")

df_net_by_activity = df_net_by_activity.merge(
    df_map_acts[["code", "value"]],
    left_on="MAIN_ACTIVITY_TYPE_CODE",
    right_on="code",
    how="left"
)

df_net_by_activity = df_net_by_activity.rename(columns={"value": "ACTIVITY_NAME"})
df_net_by_activity = df_net_by_activity.drop(columns=["code"])

# %%
df_net_by_activity.sort_values(by="TOTAL_NET_POSITION", ascending=False)
# Out:
#     MAIN_ACTIVITY_TYPE_CODE  TOTAL_NET_POSITION         2008         2009  \
# 13                       24        7.033248e+08   50014810.0   86732275.0
# 18                       29        2.438940e+08   14105998.0   44021330.0
# 31                       42        6.714697e+07    3187486.0    5474965.0
# 25                       36        4.190696e+07    3077383.0    5925100.0
# 14                       25        3.088939e+07    2815784.0    5610807.0
# 24                       35        2.687571e+07    2290379.0    2800977.0
# 4                         6        2.467718e+07    1264810.0    4583902.0
# 21                       32        1.461380e+07    3094711.0    6282288.0
# 33                       44        1.219242e+07     -65844.0     170395.0
# 7                         9        1.082914e+07     521739.0     856448.0
# 28                       39        9.496394e+06          0.0          0.0
# 27                       38        6.385903e+06      51434.0     153559.0
# 36                       99        3.187000e+06      83031.0    1805208.0
# 17                       28        1.898912e+06     184236.0     236159.0
# 6                         8        1.857608e+06     340295.0     618376.0
# 3                         5        1.301959e+06     597346.0    2011535.0
# 19                       30        5.264870e+05    3834221.0   10819514.0
# 2                         4        1.565660e+05      35201.0      24512.0
# 35                       50        0.000000e+00          0.0          0.0
# 29                       40       -2.152600e+04          0.0          0.0
# 34                       45       -3.821700e+04       2399.0       1791.0
# 5                         7       -7.482250e+05     114030.0     247911.0
# 26                       37       -1.543191e+06     258375.0     473470.0
# 11                       22       -2.196773e+06     543971.0    3794011.0
# 23                       34       -2.838390e+06     104114.0     152028.0
# 22                       33       -2.915414e+06     244701.0     546303.0
# 16                       27       -3.409181e+06      19304.0      69446.0
# 12                       23       -4.217430e+06     127478.0    1103843.0
# 32                       43       -8.455910e+06      17660.0      35254.0
# 15                       26       -8.538366e+06     101155.0     170296.0
# 20                       31       -2.163222e+07    1758876.0    4211652.0
df_net_by_activity.sort_values(by="TOTAL_NET_POSITION", ascending=False).to_excel("../data/processed/net_positions_by_activity.xlsx", index=False)

# %% [markdown]
# ## Account holders

# %%
pd.read_excel(r"../data/raw/policy_ets_registry_operators_ets_en.xlsx", nrows=0, header=0).columns.to_list()
# Out:
# ['Account Holder Name',
#  'Company Registration Nr of Account Holder',
#  'LEI',
#  'MS Registry',
#  'Installation ID',
#  'Installation Name',
#  'Activity Type',
#  'Permit ID',
#  'PERMIT_REVOCATION_DATE',
#  'Permit Expiry/Revocation Date ',
#  'Contact Country',
#  'Contact City',
#  'Contact PCode',
#  'Contact Address L1',
#  'Contact Address L2']

# %%
pd.read_excel(r"../data/raw/policy_ets_registry_operators_ets_en.xlsx",
              usecols=['Account Holder Name', 'Company Registration Nr of Account Holder', 'LEI']).nunique()
# Out:
# Account Holder Name                          10170
# Company Registration Nr of Account Holder     9651
# LEI                                           2033
# dtype: int64

# %%
df_ah = pd.read_excel(r"../data/raw/policy_ets_registry_operators_ets_en.xlsx", header=0)

# %%
df_ah.shape
# Out:
# (16394, 15)

# %% [markdown]
# ### Check unique identifier

# %%
df_ah.nunique()
# Out:
# Account Holder Name                          10170
# Company Registration Nr of Account Holder     9651
# LEI                                           2033
# MS Registry                                     31
# Installation ID                               6675
# Installation Name                            15825
# Activity Type                                   38
# Permit ID                                    16066
# PERMIT_REVOCATION_DATE                        1758
# Permit Expiry/Revocation Date                    2
# Contact Country                                109
# Contact City                                  6140
# Contact PCode                                 6743
# Contact Address L1                            9598
# Contact Address L2                            1671
# dtype: int64

# %%
df_ah[df_ah['Installation ID'] == df_ah['Installation ID'].max()]
# Out:
#       Account Holder Name Company Registration Nr of Account Holder  LEI  \
# 12324        Enemalta plc                                    C65836  NaN
#
#       MS Registry  Installation ID       Installation Name  \
# 12324          MT  220000000000002  Delimara Power Station
#
#                                            Activity Type Permit ID  \
# 12324  Combustion installations with a rated thermal ...      MT-2
#
#       PERMIT_REVOCATION_DATE Permit Expiry/Revocation Date  Contact Country  \
# 12324                    NaN                         ACTIVE              MT
#
#       Contact City Contact PCode               Contact Address L1  \
# 12324        Marsa      MRS 1000  Central Administration Building
#
#       Contact Address L2
# 12324        Church Warf

# %%
df_ah[df_ah.duplicated(subset = ['Company Registration Nr of Account Holder'], keep=False)].sort_values(['Company Registration Nr of Account Holder'])
# Out:
#                                      Account Holder Name  \
# 10471                                         Polynt SpA
# 11829                                         Polynt SpA
# 10739                                         Polynt SpA
# 12788                       Emerson Climate Technologies
# 12812                     Global Aircraft Services, Inc.
# ...                                                  ...
# 12793                              Sextant Holdings, LLC
# 14293  DESTYLACJE WAWRZYNIAK PRZEDSIĘBIORSTWO HANDLOW...
# 14626                                   Timothy E Jassak
# 14631                                       morganflight
# 16018                               Verksamhetsdepåkonto
#
#       Company Registration Nr of Account Holder                     LEI  \
# 10471                              +39035652309  8156-00770A094DCB69-38
# 11829                              +39035652309  8156-00770A094DCB69-38
# 10739                              +39035652309  8156-00770A094DCB69-38
# 12788                                         -                     NaN
# 12812                                         -                     NaN
# ...                                         ...                     ...
# 12793                                       NaN                     NaN
# 14293                                       NaN  2594-00U4TZGYALE60A-29
# 14626                                       NaN                     NaN
# 14631                                       NaN                     NaN
# 16018                                       NaN                     NaN
#
#       MS Registry  Installation ID  \
# 10471          IT              151
# 11829          IT           205586
# 10739          IT              419
# 12788          NL           202076
# 12812          NL           203446
# ...           ...              ...
# 12793          NL           202792
# 14293          PL           209222
# 14626          PT           200360
# 14631          PT           201667
# 16018          SE           216020
#
#                                        Installation Name  \
# 10471                     Stabilimento di Scanzorosciate
# 11829               Polynt S.P.A Stabilimento di Ravenna
# 10739       Polynt Stabilimento di San Giovanni Valdarno
# 12788                                              33648
# 12812                                              28885
# ...                                                  ...
# 12793                                              32631
# 14293  Kotłownia zlokalizowana w m. Zbiersk Cukrownia 61
# 14626                                             F10830
# 14631                                              29463
# 16018                               Verksamhetsdepåkonto
#
#                       Activity Type          Permit ID PERMIT_REVOCATION_DATE  \
# 10471           Combustion of fuels           IT-A-180                    NaN
# 11829  Production of bulk chemicals          IT-A-2096                    NaN
# 10739           Combustion of fuels           IT-A-634                    NaN
# 12788             Aircraft operator       NL-201000077                    NaN
# 12812             Aircraft operator       NL-201000081                    NaN
# ...                             ...                ...                    ...
# 12793             Aircraft operator       NL-201000097                    NaN
# 14293           Combustion of fuels         PL-1097-13                    NaN
# 14626             Aircraft operator       PM EA.531.01                    NaN
# 14631             Aircraft operator          ea.519.01                    NaN
# 16018            Production of pulp  SE-22-00XXXX-2021               02/01/20
#
#       Permit Expiry/Revocation Date  Contact Country    Contact City  \
# 10471                         ACTIVE              IT  SCANZOROSCIATE
# 11829                         ACTIVE              IT  SCANZOROSCIATE
# 10739                         ACTIVE              IT  SCANZOROSCIATE
# 12788                         ACTIVE              US        Vandalia
# 12812                         ACTIVE              US         Seattle
# ...                              ...             ...             ...
# 12793                         ACTIVE              US          Boston
# 14293                         ACTIVE              PL          KALISZ
# 14626                         ACTIVE              US        Waukegan
# 14631                         ACTIVE              US      Saint Paul
# 16018                        REVOKED              SE               *
#
#       Contact PCode                         Contact Address L1  \
# 10471         24020                           Via E. Fermi, 51
# 11829         24020                           Via E. Fermi, 51
# 10739         24020                           Via E. Fermi, 51
# 12788         45377                   Hangar Dr. Hangar 7 3545
# 12812         98188                      320 Andover Park East
# ...             ...                                        ...
# 12793         02199  The Prudential Tower, 800 Boylston Street
# 14293        62-800                              NIEDŹWIADY 45
# 14626         60087                       3010 Corporate Drive
# 14631         55105                             300 Airport Rd
# 16018             *                                          *
#
#       Contact Address L2
# 10471                NaN
# 11829                NaN
# 10739                NaN
# 12788                NaN
# 12812                NaN
# ...                  ...
# 12793         Suite 1380
# 14293                NaN
# 14626                NaN
# 14631                NaN
# 16018                NaN
#
# [8794 rows x 15 columns]

# %%
df_ah[df_ah.duplicated(subset = ['MS Registry', 'Installation ID'], keep=False)].sort_values(['MS Registry', 'Installation ID'])
# Out:
# Empty DataFrame
# Columns: [Account Holder Name, Company Registration Nr of Account Holder, LEI, MS Registry, Installation ID, Installation Name, Activity Type, Permit ID, PERMIT_REVOCATION_DATE, Permit Expiry/Revocation Date , Contact Country, Contact City, Contact PCode, Contact Address L1, Contact Address L2]
# Index: []

# %%
df_ah[df_ah.duplicated(subset = ['MS Registry', 'Installation ID'], keep=False)].sort_values(['MS Registry', 'Installation ID'])

# %%
df_ah[df_ah.duplicated(subset = ['MS Registry', 'Installation ID'], keep=False)].sort_values(['MS Registry', 'Installation ID'])

# %%
df_ah[df_ah.duplicated(subset = ['Account Holder Name'], keep=False)].sort_values('Account Holder Name')[['Account Holder Name',
 'Company Registration Nr of Account Holder',
 'LEI',
 'MS Registry',
 'Installation ID',
 'Installation Name',
 'Activity Type',
 'Permit ID',
 'PERMIT_REVOCATION_DATE']].head(50)
# Out:
#                                Account Holder Name  \
# 968                               "Blagoevgrad BT"
# 964                               "Blagoevgrad BT"
# 967                            '"STARTKERAMIK" OOD
# 963                            '"STARTKERAMIK" OOD
# 1934   A. Berentelg & Co. Klinker- u. Keramik-Werk
# 1933   A. Berentelg & Co. Klinker- u. Keramik-Werk
# 5543                 A.G. Siderúrgica Balboa, S.A.
# 6061                 A.G. Siderúrgica Balboa, S.A.
# 12752                   A.J.M. Dukker Holding B.V.
# 12670                   A.J.M. Dukker Holding B.V.
# 13236                             A/S Norske Shell
# 13198                             A/S Norske Shell
# 13213                             A/S Norske Shell
# 11341                       A2A AIRPORT ENERGY SPA
# 10420                       A2A AIRPORT ENERGY SPA
# 11953                          A2A AMBIENTE S.P.A.
# 11382                          A2A AMBIENTE S.P.A.
# 10440                          A2A AMBIENTE S.P.A.
# 11519                     A2A CALORE & SERVIZI Srl
# 11544                     A2A CALORE & SERVIZI Srl
# 11339                     A2A CALORE & SERVIZI Srl
# 10438                     A2A CALORE & SERVIZI Srl
# 10505                     A2A CALORE & SERVIZI Srl
# 10437                     A2A CALORE & SERVIZI Srl
# 11577                     A2A CALORE & SERVIZI Srl
# 11030                     A2A CALORE & SERVIZI Srl
# 11270                     A2A CALORE & SERVIZI Srl
# 11434                     A2A CALORE & SERVIZI Srl
# 11438                     A2A CALORE & SERVIZI Srl
# 10479                     A2A CALORE & SERVIZI Srl
# 11472                     A2A CALORE & SERVIZI Srl
# 10481                     A2A CALORE & SERVIZI Srl
# 11875                     A2A CALORE & SERVIZI Srl
# 10504                     A2A CALORE & SERVIZI Srl
# 11516                     A2A CALORE & SERVIZI Srl
# 10621                     A2A ENERGIEFUTURE S.P.A.
# 10838                     A2A ENERGIEFUTURE S.P.A.
# 10863                     A2A ENERGIEFUTURE S.P.A.
# 11381                          A2A GENCOGAS S.P.A.
# 10326                          A2A GENCOGAS S.P.A.
# 10974                          A2A GENCOGAS S.P.A.
# 10631                          A2A GENCOGAS S.P.A.
# 10522                          A2A GENCOGAS S.P.A.
# 10521                          A2A GENCOGAS S.P.A.
# 12095                          AB "Ignitis gamyba"
# 12053                          AB "Ignitis gamyba"
# 4949                     AB AZUCARERA IBERIA, S.L.
# 5239           ES              309
# 5181           ES              251
#
#                                        Installation Name  \
# 968                                       Blagoevgrad BT
# 964                              Combustion installation
# 967                                         Startkeramik
# 963     Instalacia za izrabotvane na keramichni produkti
# 1934                    Klinker- und Keramikwerk Hörstel
# 1933                        Keramikwerk Schüttorf Werk I
# 5543            A.G. Sederúrgica Balboa, S.A. (BALBOA 1)
# 6061             A.G. Siderúrgica Balboa, S.A.- Balboa 2
# 12752                               Kwekerij Dukker B.V.
# 12670                       Kwekerij Dukker Konneweg (1)
# 13236                             A/S Norske Shell Gaupe
# 13198                       A/S Norske Shell Knarrfeltet
# 13213                       A/S Norske Shell Ormen Lange
# 11341                   CENTRALE DI COGENERAZIONE LINATE
# 10420       CENTRALE DI COGENERAZIONE AEROPORTO MALPENSA
# 11953    C.le di produzione calore terleriscaldamento BG
# 11382           Centrale di teleriscaldamento di Bergamo
# 10440  CALDAIA INTEGRAZ. EMERGENZA PER TELERISCALDAMENTO
# 11519                                 Sesto San Giovanni
# 11544                                          SELINUNTE
# 11339                                           Canavese
# 10438                                          FAMAGOSTA
# 10505        CTEC - Centrale TermoElettrica Cogenerativa
# 10437                                          TECNOCITY
# 11577                             NUOVO OSPEDALE BERGAMO
# 11030                     PALAZZO DI GIUSTIZIA DI MILANO
# 11270      CENTRALE DI COGEN. E TELERISC. CITTA' DI LODI
# 11434                                          Rubattino
# 11438                                       Pompeo Leoni
# 10479                                     CTEC LAMARMORA
# 11472              IMPIANTO DI COGENERAZIONE DI RHO NORD
# 10481                                      CENTRALE NORD
# 11875                                           Comasina
# 10504        FRAZZI - Centrale di integrazione e riserva
# 11516                 CENTRALE DI COGENERAZIONE di Crema
# 10621              Centrale Termoelettrica di Monfalcone
# 10838                CENTRALE TERMOELETTRICA DI BRINDISI
# 10863    CENTRALE TERMOELETTRICA DI SAN FILIPPO DEL MELA
# 11381                                  CENTRALE DI GISSI
# 10326                CENTRALE TERMOELETTRICA DI CHIVASSO
# 10974          CENTRALE TERMOELETTRICA DI CASSANO D'ADDA
# 10631        CENTRALE TERMOELETTRICA DI PIACENZA LEVANTE
# 10522                    CENTRALE TERMOELETTRICA SERMIDE
# 10521        CENTRALE TERMOELETTRICA DI PONTI SUL MINCIO
# 12095                                 Lietuvos elektrinė
# 12053                Termofikacinė elektrinė Nr. 3 (E-3)
# 4949                           Azucarera de la Rinconada
# 5184   AB Azucarera Iberia -Instalación Azucarera de ...
# 5239                            Azucarera de Ciudad Real
# 5181   AB Azuc.Iberia-Instalación Azucarera de la Bañeza
#
#                                            Activity Type  \
# 968                                  Combustion of fuels
# 964                                  Combustion of fuels
# 967    Combustion installations with a rated thermal ...
# 963    Installations for the manufacture of ceramic p...
# 1934                             Manufacture of ceramics
# 1933                             Manufacture of ceramics
# 5543                     Production of pig iron or steel
# 6061                     Production of pig iron or steel
# 12752  Combustion installations with a rated thermal ...
# 12670  Combustion installations with a rated thermal ...
# 13236                                Combustion of fuels
# 13198                                Combustion of fuels
# 13213                                Combustion of fuels
# 11341                                Combustion of fuels
# 10420                                Combustion of fuels
# 11953                                Combustion of fuels
# 11382                                Combustion of fuels
# 10440                                Combustion of fuels
# 11519                                Combustion of fuels
# 11544                                Combustion of fuels
# 11339                                Combustion of fuels
# 10438                                Combustion of fuels
# 10505                                Combustion of fuels
# 10437                                Combustion of fuels
# 11577                                Combustion of fuels
# 11030  Combustion installations with a rated thermal ...
# 11270                                Combustion of fuels
# 11434                                Combustion of fuels
# 11438                                Combustion of fuels
# 10479                                Combustion of fuels
# 11472                                Combustion of fuels
# 10481                                Combustion of fuels
# 11875                                Combustion of fuels
# 10504  Combustion installations with a rated thermal ...
# 11516                                Combustion of fuels
# 10621                                Combustion of fuels
# 10838                                Combustion of fuels
# 10863                                Combustion of fuels
# 11381                                Combustion of fuels
# 10326                                Combustion of fuels
# 10974                                Combustion of fuels
# 10631                                Combustion of fuels
# 10522                                Combustion of fuels
# 10521                                Combustion of fuels
# 12095                                Combustion of fuels
# 12053                                Combustion of fuels
# 4949   Combustion installations with a rated thermal ...
# 5184                                 Combustion of fuels
# 5239   Combustion installations with a rated thermal ...
# 5181                                 Combustion of fuels
#
#                          Permit ID PERMIT_REVOCATION_DATE
# 968                        BG-P148                    NaN
# 964                         BG-148               31/12/10
# 967                        BG-P140               14/08/13
# 963                         BG-140               14/08/13
# 1934                    14260-0171                    NaN
# 1933                    14260-0170                    NaN
# 5543                ES110605000717               19/05/14
# 6061                ES110601001363                    NaN
# 12752                 NL-200900045               22/08/11
# 12670                 NL-200700083               31/12/12
# 13236                 NO-2023-5033                    NaN
# 13198                  NO-2013-764                    NaN
# 13213                NO-2017-11692                    NaN
# 11341                    IT-A-1505                    NaN
# 10420                     IT-A-121                    NaN
# 11953                    IT-A-1533                    NaN
# 11382                    IT-A-1533               01/01/13
# 10440                     IT-A-144                    NaN
# 11519                    IT-A-1666                    NaN
# 11544                    IT-A-1675                    NaN
# 11339                    IT-A-1513                    NaN
# 10438                     IT-A-142                    NaN
# 10505                     IT-A-228                    NaN
# 10437                     IT-A-141                    NaN
# 11577                    IT-A-1665                    NaN
# 11030                    IT-A-1052               28/12/12
# 11270                     IT-A-858                    NaN
# 11434                    IT-A-1554                    NaN
# 11438                    IT-A-1553                    NaN
# 10479                     IT-A-189                    NaN
# 11472                    IT-A-1619                    NaN
# 10481                     IT-A-191                    NaN
# 11875                    IT-A-2395               12/01/24
# 10504                     IT-A-227                    NaN
# 11516                    IT-A-1610                    NaN
# 10621                     IT-A-380                    NaN
# 10838                     IT-A-765                    NaN
# 10863                     IT-A-804                    NaN
# 11381                    IT-A-1526                    NaN
# 10326                       IT-A-7                    NaN
# 10974                     IT-A-986                    NaN
# 10631                     IT-A-391                    NaN
# 10522                     IT-A-247                    NaN
# 10521                     IT-A-245                    NaN
# 12095                 T-V-1-2-2014                    NaN
# 12053  VR-4-7-V-01-37-T-V-7-5-2014                    NaN
# 4949                ES014101000019               04/07/11
# 5184                ES064901000326                    NaN
# 5239                ES071301000388                    NaN
# 5181                ES062401000323                    NaN
